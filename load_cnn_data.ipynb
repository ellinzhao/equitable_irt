# %% [markdown]
# ## Imports

# %%
# %config InlineBackend.figure_format='retina'
# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

# %%
import glob
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pyrtools as pt
from scipy.constants import convert_temperature as conv_temp
from torchvision import transforms

# %%
from solar_cnn.dataset import SolarDataset

# %% [markdown]
# ## Loading data

# %%
# Calculate mean and std of dataset
# Recalculate when we add more data!

calc_stats = False
if calc_stats:
    dataset_dir = '/Users/ellin/Projects/therm/dataset/ml_data'
    sids = glob(f'{dataset_dir}/**')
    solar_ds = SolarDataset(dataset_dir, sids)
    ims = []
    for i in range(len(solar_ds)):
        ims += [solar_ds[i][0]]
    mean, std = np.mean(ims), np.std(ims)
else:
    mean, std = 90.14835, 5.923113

tform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
    transforms.Resize((64, 64), antialias=None),
])

# %%
dataset_dir = '/Users/ellin/Projects/therm/dataset/ml_data'
sids = glob.glob(f'{dataset_dir}/**')[:2]
solar_ds = SolarDataset(dataset_dir, sids, transform=tform)
